# %%
import numpy as np
import pandas as pd
import csv

# %%
df = pd.read_csv('java-med.train_base.c2s', nrows=20, sep="#", header=None)

# %%
df.to_csv('java-med.train.c2s', header=False, quoting=3, quotechar='',escapechar='\\', index=False)

# %%
df
# Out:
#                                                     0
# 0   get|internal|call|context|factory internal|cal...
# 1   complete|initialization session|info,Cls1|Prm|...
# 2   new|buffer mtl|buffer,Cls0|Mth|Nm1,METHOD_NAME...
# 3   create|layout|manager override,Nm0|MarkerExpr|...
# 4   test|compilation|actions|for|optimized test,Nm...
# 5   get|open|projects project,Cls0|Cls|Mth|Nm1,MET...
# 6   query override,Nm0|MarkerExpr|Mth|Cls1,query o...
# 7   test|set|alpha test,Nm0|MarkerExpr|Mth|Void1,v...
# 8   get|simulator|device|for|platform|type skylark...
# 9   equals override,Nm0|MarkerExpr|Mth|Prim1,boole...
# 10  revert|to|original|streams after,Nm0|MarkerExp...
# 11  test|commit test,Nm0|MarkerExpr|Mth|Void1,void...
# 12  intersect|with not|null,Nm0|MarkerExpr|Mth|Cls...
# 13  get|field|value object,Cls0|Mth|Nm1,METHOD_NAM...
# 14  get|first|album string,Cls0|Mth|Nm1,METHOD_NAM...
# 15  create|space|before|l|brace void,Void0|Mth|Nm1...
# ...
