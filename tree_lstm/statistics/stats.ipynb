# %%
# !pwd
# Out:
# /home/anton/optimization-methods/statistics

# %%
# %cd ../embeddings-for-trees
# Out:
# /home/anton/optimization-methods/embeddings-for-trees

# %%
import os
import torch
from data_module.jsonl_data_module import JsonlDataModule
from omegaconf import OmegaConf
from utils.common import PAD, UNK, EOS, SOS

import matplotlib.pyplot as plt

import json
import pickle
import itertools
from collections import defaultdict

from nltk.translate.meteor_score import single_meteor_score
from nltk.translate.bleu_score import corpus_bleu, sentence_bleu
from rouge import Rouge
from bert_score import score as bert_score

from scipy.stats import wilcoxon, mannwhitneyu
from time import perf_counter
# Out:
# Using backend: pytorch

# %%
config = OmegaConf.load("config/tree_lstm_med_10per1.yaml")

# %%
data_module = JsonlDataModule(config)
data_module.prepare_data()
data_module.setup()
# Out:
# Dataset is already downloaded

# %%
id_to_label = data_module._vocabulary.id_to_label

# %%
def ids_to_text(ids):
    res = []
    for idx in ids:
        if idx in [0, 2]:  # PAD, SOS
            continue
        elif idx == 3:  # EOS
            return res
        res.append(id_to_label[idx.item()])
    return res

# %%
def get_hyps_refs(predict_file = "/home/anton/opt-exps-data/outputs/25per/SGD_25per/Momentum_test_outputs.pkl",
                  use_first=10):
    start = perf_counter()
    test_dataloader = data_module.test_dataloader()
    predictions = torch.load(f"{predict_file}", map_location=torch.device('cpu'))

    hyps = []; refs = []
    
    if use_first is None:
        x = zip(predictions, test_dataloader)
    else:
        x = itertools.islice(zip(predictions, test_dataloader), use_first)
    
    for batch_our, batch_ref in x:
        batch_ref = batch_ref[0]
        for batch_idx in range(batch_our.size(1)):
            res_our = ids_to_text(batch_our[:, batch_idx])
            res_ref = ids_to_text(batch_ref[:, batch_idx])
            
            hyps.append(' '.join(res_our)); refs.append(' '.join(res_ref))
    finish = perf_counter()
    print(f"Preprocessing time elapsed: {finish - start}, s")

    return hyps, refs

# %%
class Metrics:
    def __init__(self, hyps, refs):
        self.hyps = hyps
        self.refs = refs
    
    def get_statistics(self, with_symbolic=False, bert=False):
        result = {
            'scores': {},
            'score': {}
        }
        for func in dir(Metrics):
            if callable(getattr(Metrics, func)) and func[0] != '_' and func != 'get_statistics':
                if (not with_symbolic and 'symb' in func) or (not bert and func == 'bert'):
                    continue
                print(f'Calculating {func} metric')
                start = perf_counter()
                metric_result = getattr(Metrics, func)(self)
                result['scores'].update(metric_result['scores'])
                result['score'].update(metric_result['score'])
                finish = perf_counter()
                print('Metric is calculated. Elapsed time:', finish - start)
    
        return result
    
    def bert(self):
        (P, R, F), hashname = bert_score(self.hyps, self.refs, lang="en", return_hash=True)
        return {
            'scores': {
                'bert-P': P.cpu().detach().numpy(),
                'bert-R': R.cpu().detach().numpy(),
                'bert-F': F.cpu().detach().numpy()
            },
            'score': {
                'bert-P': P.mean().item(),
                'bert-R': R.mean().item(),
                'bert-F': F.mean().item()
            }
        }
    
    def meteor(self):
        scores = []
        for hyp, ref in zip(self.hyps, self.refs):
            scores.append(single_meteor_score(ref, hyp))
        
        return {
            'scores': {
                'meteor': np.array(scores)
            },
            'score': {
                'meteor': np.mean(scores)
            }
        }

    def bleu(self):
        
        def bleu_weights(l):
            length = len(l)
            if length >= 4:
                return (0.25, 0.25, 0.25, 0.25)
            wt = [1 / length for _ in range(length)]
            wt.extend([0 for _ in range(4-length)])
            return tuple(wt)
        
        scores = []
        
        
        
        for hyp, ref in zip(self.hyps, self.refs):
            scores.append(sentence_bleu([ref], hyp, weights=bleu_weights(ref)))
        
        return {
            'scores': {
                'bleu': np.array(scores)
            },
            'score': {
                'bleu': corpus_bleu([[ref] for ref in self.refs], self.hyps)
            }
        }
    
    def symb_rouge_l(self):
        rouge = Rouge(metrics=['rouge-l'])
        scores_dict = defaultdict(list)
        
        hyps_symb = [' '.join(h.replace(' ', '')) for h in hyps]
        refs_symb = [' '.join(r.replace(' ', '')) for r in refs]

        scores = rouge.get_scores(hyps_symb, refs_symb)
        for score in scores:
            batch = {}
            for sub in score:
                batch.update({sub + k.upper(): v for k, v in score[sub].items()})

            for title in batch:
                scores_dict['symb-' + title].append(batch[title])

        scores_dict = dict(scores_dict)
        score_dict = {}
        for title in scores_dict:
            scores_dict[title] = np.array(scores_dict[title])
            score_dict[title] = scores_dict[title].mean()
        
        return {
            'scores': scores_dict,
            'score': score_dict
        }
    
    def rouge(self):
        rouge = Rouge()
        scores_dict = defaultdict(list)

        scores = rouge.get_scores(hyps, refs)
        for score in scores:
            batch = {}
            for sub in score:
                batch.update({sub + k.upper(): v for k, v in score[sub].items()})

            for title in batch:
                scores_dict[title].append(batch[title])

        scores_dict = dict(scores_dict)
        score_dict = {}
        for title in scores_dict:
            scores_dict[title] = np.array(scores_dict[title])
            score_dict[title] = scores_dict[title].mean()
        
        return {
            'scores': scores_dict,
            'score': score_dict
        }

# %% [markdown]
# ## Check

# %%
# %%time
hyps, refs = get_hyps_refs()
# Out:
# Preprocessing time elapsed: 14.219671744001971, s
# CPU times: user 1.89 s, sys: 466 ms, total: 2.36 s
# Wall time: 14.2 s

# %%
metrics = Metrics(hyps, refs)
test_metrics = metrics.get_statistics(with_symbolic=False, bert=False)
# Out:
# Calculating bleu metric
# Metric is calculated. Elapsed time: 1.0576067639995017
# Calculating meteor metric
# Metric is calculated. Elapsed time: 0.7424251960037509
# Calculating rouge metric
# Metric is calculated. Elapsed time: 0.4186929900024552

# %%
hyps[:10], refs[:10]
# Out:
# (['get id',
#   'on existing',
#   'on existing',
#   'on existing',
#   'on existing',
#   'get view',
#   'get write',
#   'set on touch max',
#   'on item item',
#   'get context'],
#  ['get id',
#   'on measure',
#   'on measure',
#   'on measure',
#   'on measure',
#   'get view',
#   'get text',
#   'set on touch listener',
#   'on dialog item click',
#   'get text view'])

# %%
for k, v in test_metrics['scores'].items():
    print(k, v[:10])
# Out:
# bleu [1.00000000e+00 3.87192832e-78 3.87192832e-78 3.87192832e-78
#  3.87192832e-78 1.00000000e+00 3.54948106e-01 5.79217451e-01
#  2.72661731e-01 3.91236061e-01]
# meteor [0.9375     0.25       0.25       0.25       0.25       0.9375
#  0.25       0.73611111 0.25641026 0.17241379]
# rouge-1F [1.         0.5        0.5        0.5        0.5        1.
#  0.5        0.75       0.57142857 0.4       ]
# rouge-1P [1.         0.5        0.5        0.5        0.5        1.
#  0.5        0.75       0.66666667 0.5       ]
# rouge-1R [1.         0.5        0.5        0.5        0.5        1.
#  0.5        0.75       0.5        0.33333333]
# rouge-2F [1.         0.         0.         0.         0.         1.
#  0.         0.66666666 0.         0.        ]
# rouge-2P [1.         0.         0.         0.         0.         1.
#  0.         0.66666667 0.         0.        ]
# rouge-2R [1.         0.         0.         0.         0.         1.
#  0.         0.66666667 0.         0.        ]
# rouge-lF [1.         0.5        0.5        0.5        0.5        1.
#  0.5        0.75       0.66666666 0.4       ]
# rouge-lP [1.   0.5  0.5  0.5  0.5  1.   0.5  0.75 1.   0.5 ]
# rouge-lR [1.         0.5        0.5        0.5        0.5        1.
#  0.5        0.75       0.5        0.33333333]

# %% [markdown]
# ## Methods reports

# %%
global_methods = [
#     ('Adam', 'adam_global_predictions.pkl'),
#     ('Cyclic SGD', './outputs/global_Cycle_SGD_test_outputs.pkl'),
#     ('Lamb', 'Lamb_global_predictions.pkl'),
#     ('LaRAdam', 'Lookahead_Radam_standart_lr/tensor/Lookahead_RAdam_test_outputs.pkl'),
#     ('LaAdam', './outputs/global_Lookahead_test_outputs.pkl'),
    ('RAdam', 'RAdam_global/tensor/RAdam_test_outputs.pkl'),
    ('SGD', 'SGD_global/tensor/Momentum_test_outputs.pkl'),
    ('LaSGD', 'Lookahead_global_predictions.pkl')
]

# %%
if os.path.isfile('/home/anton/data/global_methods_report.data'):

    with open('/home/anton/data/global_methods_report.data', 'rb') as fp:
        global_methods_report = pickle.load(fp)

else:
#     global_methods_report = {}

    for method, path in global_methods:
        hyps, refs = get_hyps_refs(predict_file=DATA_DIR+path, use_first=None)
        metrics = Metrics(hyps, refs)
        global_methods_report[method] = metrics.get_statistics(with_symbolic=True, bert=False)
        print(method, global_methods_report[method])

    with open('/home/anton/data/global_methods_report.data', 'wb') as fp:
        pickle.dump(global_methods_report, fp)
# Out:
# Preprocessing time elapsed: 995.5748151590014, s
# Calculating bleu metric
# Metric is calculated. Elapsed time: 80.88183521700012
# Calculating meteor metric
# Metric is calculated. Elapsed time: 53.89030301400089
# Calculating rouge metric
# Metric is calculated. Elapsed time: 36.001044742000886
# Calculating symb_rouge_l metric
# Metric is calculated. Elapsed time: 64.01198457699866
# RAdam {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#        6.07291035e-155, 0.00000000e+000, 0.00000000e+000]), 'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]), 'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]), 'symb-rouge-lF': array([1. , 1. , 1. , ..., 0.3, 0. , 0. ]), 'symb-rouge-lP': array([1. , 1. , 1. , ..., 0.3, 0. , 0. ]), 'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.3, 0. , 0. ])}, 'score': {'bleu': 0.31078324625949116, 'meteor': 0.2783913447653553, 'rouge-1F': 0.3879209486975971, 'rouge-1P': 0.41711343356680664, 'rouge-1R': 0.3845498545563237, 'rouge-2F': 0.17807661877470246, 'rouge-2P': 0.1831496508391891, 'rouge-2R': 0.1778966127729259, 'rouge-lF': 0.4010246669663175, 'rouge-lP': 0.44987782217766614, 'rouge-lR': 0.38397491060309075, 'symb-rouge-lF': 0.5699453239559463, 'symb-rouge-lP': 0.6832333586575338, 'symb-rouge-lR': 0.5332152411568911}}
# Preprocessing time elapsed: 1135.7363418149998, s
# Calculating bleu metric
# Metric is calculated. Elapsed time: 85.91727841699867
# Calculating meteor metric
# Metric is calculated. Elapsed time: 52.9080505840011
# Calculating rouge metric
# Metric is calculated. Elapsed time: 38.32893329200124
# Calculating symb_rouge_l metric
# Metric is calculated. Elapsed time: 52.354808316000344
# SGD {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#        4.93832578e-233, 0.00000000e+000, 0.00000000e+000]), 'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]), 'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]), 'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.15384615, 0.        ,
#        0.        ]), 'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.33333333, 0.        ,
#        0.        ]), 'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.1, 0. , 0. ])}, 'score': {'bleu': 0.2777456863399343, 'meteor': 0.2646716025310887, 'rouge-1F': 0.38389892329773945, 'rouge-1P': 0.43264142949335693, 'rouge-1R': 0.3708640633465195, 'rouge-2F': 0.15965635515846616, 'rouge-2P': 0.16688765600511274, 'rouge-2R': 0.15799143856754216, 'rouge-lF': 0.3940349092697178, 'rouge-lP': 0.45886446336964587, 'rouge-lR': 0.3703137525138172, 'symb-rouge-lF': 0.5556912867574134, 'symb-rouge-lP': 0.6902638061975966, 'symb-rouge-lR': 0.5107360951960612}}
# Preprocessing time elapsed: 904.2954766399998, s
# Calculating bleu metric
# Metric is calculated. Elapsed time: 70.1068541780005
# Calculating meteor metric
# Metric is calculated. Elapsed time: 44.254602623999745
# Calculating rouge metric
# Metric is calculated. Elapsed time: 35.32095706399923
# Calculating symb_rouge_l metric
# Metric is calculated. Elapsed time: 49.82581344200116
# LaSGD {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#        4.93832578e-233, 0.00000000e+000, 0.00000000e+000]), 'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]), 'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]), 'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.15384615, 0.        ,
#        0.        ]), 'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.33333333, 0.        ,
#        0.        ]), 'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.1, 0. , 0. ])}, 'score': {'bleu': 0.24514170763158594, 'meteor': 0.24750085839818037, 'rouge-1F': 0.3689483222826558, 'rouge-1P': 0.42501341037350154, 'rouge-1R': 0.35284379163884694, 'rouge-2F': 0.14240959164215686, 'rouge-2P': 0.14968236444919472, 'rouge-2R': 0.14048511398315214, 'rouge-lF': 0.37915613746973303, 'rouge-lP': 0.4510352049370713, 'rouge-lR': 0.35256079536741075, 'symb-rouge-lF': 0.5369581458712017, 'symb-rouge-lP': 0.6873876233953559, 'symb-rouge-lR': 0.48687737326382463}}

# %%
global_methods_report
# Out:
# {'Adam': {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#           1.13491276e-231, 8.84484440e-232, 0.00000000e+000]),
#    'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]),
#    'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]),
#    'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.33333333, 0.18181818,
#           0.        ]),
#    'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.375     , 0.16666667,
#           0.        ]),
#    'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.3, 0.2, 0. ])},
#   'score': {'bleu': 0.2473695397571092,
#    'meteor': 0.2442593625233599,
#    'rouge-1F': 0.35564469697045975,
#    'rouge-1P': 0.3916712930502008,
#    'rouge-1R': 0.3481059005420179,
#    'rouge-2F': 0.14160716195789708,
#    'rouge-2P': 0.14598144736492577,
#    'rouge-2R': 0.14106221765945842,
#    'rouge-lF': 0.36518472954921566,
#    'rouge-lP': 0.4156373158626803,
#    'rouge-lR': 0.3479342834775493,
#    'symb-rouge-lF': 0.5355527538936309,
#    'symb-rouge-lP': 0.6649887983399876,
#    'symb-rouge-lR': 0.49367466202792953}},
#  'Lamb': {'scores': {'bleu': array([1.        , 1.        , 1.        , ..., 0.39142369, 0.        ,
#           0.        ]),
#    'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.25  , 0.    , 0.    ]),
#    'rouge-1F': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-1P': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-1R': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lF': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-lP': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-lR': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.58823529, 0.        ,
#           0.        ]),
#    'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.71428571, 0.        ,
#           0.        ]),
#    'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ])},
#   'score': {'bleu': 0.31576961782899315,
#    'meteor': 0.28534654241234975,
#    'rouge-1F': 0.3980293636173818,
#    'rouge-1P': 0.43506358961377445,
#    'rouge-1R': 0.39214800029733854,
#    'rouge-2F': 0.18087299676891758,
#    'rouge-2P': 0.1867766183357475,
#    'rouge-2R': 0.18048168409736182,
#    'rouge-lF': 0.409513294543072,
#    'rouge-lP': 0.463702259795823,
#    'rouge-lR': 0.3912147487990936,
#    'symb-rouge-lF': 0.5733783731760014,
#    'symb-rouge-lP': 0.6883180458763324,
#    'symb-rouge-lR': 0.5366558314689206}},
#  'LaRAdam': {'scores': {'bleu': array([1.        , 1.        , 1.        , ..., 0.39142369, 0.        ,
#           0.        ]),
#    'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.25  , 0.    , 0.    ]),
#    'rouge-1F': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-1P': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-1R': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lF': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-lP': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'rouge-lR': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ]),
#    'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.58823529, 0.        ,
#           0.        ]),
#    'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.71428571, 0.        ,
#           0.        ]),
#    'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.5, 0. , 0. ])},
#   'score': {'bleu': 0.36474375955099086,
#    'meteor': 0.3151329140596455,
#    'rouge-1F': 0.43095621531528033,
#    'rouge-1P': 0.464020051605662,
#    'rouge-1R': 0.4273676926858047,
#    'rouge-2F': 0.20802307661373898,
#    'rouge-2P': 0.21404581202350767,
#    'rouge-2R': 0.20789975357950388,
#    'rouge-lF': 0.4427550307033276,
#    'rouge-lP': 0.4948139133490083,
#    'rouge-lR': 0.42603185094852586,
#    'symb-rouge-lF': 0.6076546020914739,
#    'symb-rouge-lP': 0.702350475566257,
#    'symb-rouge-lR': 0.5794167780440348}},
#  'RAdam': {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#           6.07291035e-155, 0.00000000e+000, 0.00000000e+000]),
#    'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]),
#    'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]),
#    'symb-rouge-lF': array([1. , 1. , 1. , ..., 0.3, 0. , 0. ]),
#    'symb-rouge-lP': array([1. , 1. , 1. , ..., 0.3, 0. , 0. ]),
#    'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.3, 0. , 0. ])},
#   'score': {'bleu': 0.31078324625949116,
#    'meteor': 0.2783913447653553,
#    'rouge-1F': 0.3879209486975971,
#    'rouge-1P': 0.41711343356680664,
#    'rouge-1R': 0.3845498545563237,
#    'rouge-2F': 0.17807661877470246,
#    'rouge-2P': 0.1831496508391891,
#    'rouge-2R': 0.1778966127729259,
#    'rouge-lF': 0.4010246669663175,
#    'rouge-lP': 0.44987782217766614,
#    'rouge-lR': 0.38397491060309075,
#    'symb-rouge-lF': 0.5699453239559463,
#    'symb-rouge-lP': 0.6832333586575338,
#    'symb-rouge-lR': 0.5332152411568911}},
#  'SGD': {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#           4.93832578e-233, 0.00000000e+000, 0.00000000e+000]),
#    'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]),
#    'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]),
#    'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.15384615, 0.        ,
#           0.        ]),
#    'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.33333333, 0.        ,
#           0.        ]),
#    'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.1, 0. , 0. ])},
#   'score': {'bleu': 0.2777456863399343,
#    'meteor': 0.2646716025310887,
#    'rouge-1F': 0.38389892329773945,
#    'rouge-1P': 0.43264142949335693,
#    'rouge-1R': 0.3708640633465195,
#    'rouge-2F': 0.15965635515846616,
#    'rouge-2P': 0.16688765600511274,
#    'rouge-2R': 0.15799143856754216,
#    'rouge-lF': 0.3940349092697178,
#    'rouge-lP': 0.45886446336964587,
#    'rouge-lR': 0.3703137525138172,
#    'symb-rouge-lF': 0.5556912867574134,
#    'symb-rouge-lP': 0.6902638061975966,
#    'symb-rouge-lR': 0.5107360951960612}},
#  'LaSGD': {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#           4.93832578e-233, 0.00000000e+000, 0.00000000e+000]),
#    'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]),
#    'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]),
#    'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]),
#    'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.15384615, 0.        ,
#           0.        ]),
#    'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.33333333, 0.        ,
#           0.        ]),
#    'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.1, 0. , 0. ])},
#   'score': {'bleu': 0.24514170763158594,
#    'meteor': 0.24750085839818037,
#    'rouge-1F': 0.3689483222826558,
#    'rouge-1P': 0.42501341037350154,
#    'rouge-1R': 0.35284379163884694,
#    'rouge-2F': 0.14240959164215686,
#    'rouge-2P': 0.14968236444919472,
#    'rouge-2R': 0.14048511398315214,
#    'rouge-lF': 0.37915613746973303,
#    'rouge-lP': 0.4510352049370713,
#    'rouge-lR': 0.35256079536741075,
#    'symb-rouge-lF': 0.5369581458712017,
#    'symb-rouge-lP': 0.6873876233953559,
#    'symb-rouge-lR': 0.48687737326382463}}}

# %%
local_methods = [
#     ('Adadelta', 'Adadelta_local/tensor/Adadelta_test_outputs.pkl'),
#     ('Barzilai-Borwein', 'BB_local/tensor/BB_test_outputs.pkl'),
#     ('LaRAdam', 'LaRAdam_local/tensor/Lookahead_RAdam_test_outputs.pkl'),
#     ('Adam', 'Adam_local/tensor/Adam_test_outputs.pkl'),
    ('SVRG', 'SVRG_local/tensor/SVRG_test_outputs.pkl'),
    ('SWA', 'SWA_local_const/tensor/SWA_test_outputs.pkl'),
]

# %%
if os.path.isfile('local_methods_report.data'):

    with open('local_methods_report.data', 'rb') as fp:
        local_methods_report = pickle.load(fp)

else:
#     local_methods_report = {}

    for method, path in local_methods:
        hyps, refs = get_hyps_refs(predict_file=DATA_DIR+path, use_first=None)
        metrics = Metrics(hyps, refs)
        local_methods_report[method] = metrics.get_statistics(with_symbolic=True, bert=False)
        print(method, local_methods_report[method])

    with open('local_methods_report.data', 'wb') as fp:
        pickle.dump(local_methods_report, fp)
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f558cf01310>
# Traceback (most recent call last):
#   File "/home/anton/opt-met-exps/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1324, in __del__
#     self._shutdown_workers()
#   File "/home/anton/opt-met-exps/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1316, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f558cf01310>
# Traceback (most recent call last):
#   File "/home/anton/opt-met-exps/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1324, in __del__
#     self._shutdown_workers()
#   File "/home/anton/opt-met-exps/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1316, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Preprocessing time elapsed: 983.2660813690018, s
# Calculating bleu metric
# Metric is calculated. Elapsed time: 75.26180082100109
# Calculating meteor metric
# Metric is calculated. Elapsed time: 44.55030993500259
# Calculating rouge metric
# Metric is calculated. Elapsed time: 32.516790330999356
# Calculating symb_rouge_l metric
# Metric is calculated. Elapsed time: 60.80438553199929
# SVRG {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#        4.93832578e-233, 0.00000000e+000, 0.00000000e+000]), 'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]), 'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]), 'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.15384615, 0.        ,
#        0.        ]), 'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.33333333, 0.        ,
#        0.        ]), 'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.1, 0. , 0. ])}, 'score': {'bleu': 0.3662603439013418, 'meteor': 0.3172045447810609, 'rouge-1F': 0.43061725201226414, 'rouge-1P': 0.46107268255017403, 'rouge-1R': 0.4281547806000391, 'rouge-2F': 0.2106895140687501, 'rouge-2P': 0.21659619384245646, 'rouge-2R': 0.210669327758011, 'rouge-lF': 0.44186090665507705, 'rouge-lP': 0.49007501772981954, 'rouge-lR': 0.42691978732699054, 'symb-rouge-lF': 0.6071045572690423, 'symb-rouge-lP': 0.7002172926747087, 'symb-rouge-lR': 0.579377981982626}}
# Preprocessing time elapsed: 1015.7641179090024, s
# Calculating bleu metric
# Metric is calculated. Elapsed time: 75.67493057799948
# Calculating meteor metric
# Metric is calculated. Elapsed time: 44.252205009001045
# Calculating rouge metric
# Metric is calculated. Elapsed time: 32.55571752800097
# Calculating symb_rouge_l metric
# Metric is calculated. Elapsed time: 63.775176653001836
# SWA {'scores': {'bleu': array([1.00000000e+000, 1.00000000e+000, 1.00000000e+000, ...,
#        8.87581497e-232, 0.00000000e+000, 0.00000000e+000]), 'meteor': array([0.9375, 0.9375, 0.9375, ..., 0.    , 0.    , 0.    ]), 'rouge-1F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-1R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2F': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2P': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-2R': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lF': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lP': array([1., 1., 1., ..., 0., 0., 0.]), 'rouge-lR': array([1., 1., 1., ..., 0., 0., 0.]), 'symb-rouge-lF': array([1.        , 1.        , 1.        , ..., 0.23529411, 0.        ,
#        0.        ]), 'symb-rouge-lP': array([1.        , 1.        , 1.        , ..., 0.28571429, 0.        ,
#        0.        ]), 'symb-rouge-lR': array([1. , 1. , 1. , ..., 0.2, 0. , 0. ])}, 'score': {'bleu': 0.38511112697257205, 'meteor': 0.32625027770466625, 'rouge-1F': 0.4406950572870883, 'rouge-1P': 0.4692494164283158, 'rouge-1R': 0.439336598923911, 'rouge-2F': 0.2172621907472461, 'rouge-2P': 0.22298269587460526, 'rouge-2R': 0.21738135642216821, 'rouge-lF': 0.4522543294472528, 'rouge-lP': 0.49906143011392856, 'rouge-lR': 0.4379511058786657, 'symb-rouge-lF': 0.6178447466262633, 'symb-rouge-lP': 0.7010800667390553, 'symb-rouge-lR': 0.5944273804547128}}

# %%
for method in global_methods_report:
    print(method, global_methods_report[method]['score'])
    print()
# Out:
# Adam {'bleu': 0.2473695397571092, 'meteor': 0.2442593625233599, 'rouge-1F': 0.35564469697045975, 'rouge-1P': 0.3916712930502008, 'rouge-1R': 0.3481059005420179, 'rouge-2F': 0.14160716195789708, 'rouge-2P': 0.14598144736492577, 'rouge-2R': 0.14106221765945842, 'rouge-lF': 0.36518472954921566, 'rouge-lP': 0.4156373158626803, 'rouge-lR': 0.3479342834775493, 'symb-rouge-lF': 0.5355527538936309, 'symb-rouge-lP': 0.6649887983399876, 'symb-rouge-lR': 0.49367466202792953}
#
# Lamb {'bleu': 0.31576961782899315, 'meteor': 0.28534654241234975, 'rouge-1F': 0.3980293636173818, 'rouge-1P': 0.43506358961377445, 'rouge-1R': 0.39214800029733854, 'rouge-2F': 0.18087299676891758, 'rouge-2P': 0.1867766183357475, 'rouge-2R': 0.18048168409736182, 'rouge-lF': 0.409513294543072, 'rouge-lP': 0.463702259795823, 'rouge-lR': 0.3912147487990936, 'symb-rouge-lF': 0.5733783731760014, 'symb-rouge-lP': 0.6883180458763324, 'symb-rouge-lR': 0.5366558314689206}
#
# LaRAdam {'bleu': 0.36474375955099086, 'meteor': 0.3151329140596455, 'rouge-1F': 0.43095621531528033, 'rouge-1P': 0.464020051605662, 'rouge-1R': 0.4273676926858047, 'rouge-2F': 0.20802307661373898, 'rouge-2P': 0.21404581202350767, 'rouge-2R': 0.20789975357950388, 'rouge-lF': 0.4427550307033276, 'rouge-lP': 0.4948139133490083, 'rouge-lR': 0.42603185094852586, 'symb-rouge-lF': 0.6076546020914739, 'symb-rouge-lP': 0.702350475566257, 'symb-rouge-lR': 0.5794167780440348}
#
# RAdam {'bleu': 0.31078324625949116, 'meteor': 0.2783913447653553, 'rouge-1F': 0.3879209486975971, 'rouge-1P': 0.41711343356680664, 'rouge-1R': 0.3845498545563237, 'rouge-2F': 0.17807661877470246, 'rouge-2P': 0.1831496508391891, 'rouge-2R': 0.1778966127729259, 'rouge-lF': 0.4010246669663175, 'rouge-lP': 0.44987782217766614, 'rouge-lR': 0.38397491060309075, 'symb-rouge-lF': 0.5699453239559463, 'symb-rouge-lP': 0.6832333586575338, 'symb-rouge-lR': 0.5332152411568911}
#
# SGD {'bleu': 0.2777456863399343, 'meteor': 0.2646716025310887, 'rouge-1F': 0.38389892329773945, 'rouge-1P': 0.43264142949335693, 'rouge-1R': 0.3708640633465195, 'rouge-2F': 0.15965635515846616, 'rouge-2P': 0.16688765600511274, 'rouge-2R': 0.15799143856754216, 'rouge-lF': 0.3940349092697178, 'rouge-lP': 0.45886446336964587, 'rouge-lR': 0.3703137525138172, 'symb-rouge-lF': 0.5556912867574134, 'symb-rouge-lP': 0.6902638061975966, 'symb-rouge-lR': 0.5107360951960612}
#
# LaSGD {'bleu': 0.24514170763158594, 'meteor': 0.24750085839818037, 'rouge-1F': 0.3689483222826558, 'rouge-1P': 0.42501341037350154, 'rouge-1R': 0.35284379163884694, 'rouge-2F': 0.14240959164215686, 'rouge-2P': 0.14968236444919472, 'rouge-2R': 0.14048511398315214, 'rouge-lF': 0.37915613746973303, 'rouge-lP': 0.4510352049370713, 'rouge-lR': 0.35256079536741075, 'symb-rouge-lF': 0.5369581458712017, 'symb-rouge-lP': 0.6873876233953559, 'symb-rouge-lR': 0.48687737326382463}

# %%
for method1, method2 in itertools.combinations(global_methods_report, 2):
    print(method1, '-', method2)
    for score in global_methods_report[method1]['score']:
        print(score, end=' ')
        h1 = None
        if global_methods_report[method1]['score'][score] > global_methods_report[method2]['score'][score]:
            pc = round(100 * (global_methods_report[method1]['score'][score] - global_methods_report[method2]['score'][score]) / global_methods_report[method2]['score'][score], 0)
            print('>', f'({pc}%)', end=' ')
            h1 = 'less'
        else:
            pc = round(100 * (global_methods_report[method2]['score'][score] - global_methods_report[method1]['score'][score]) / global_methods_report[method1]['score'][score], 0)
            print('<', f'({pc}%)', end=' ')
            h1 = 'greater'
            
        print()
        w, p = wilcoxon(
            global_methods_report[method1]['scores'][score],
            global_methods_report[method2]['scores'][score],
            alternative=h1
        )
        print('wilcoxon signed-rank: w =', round(int(w), -4), ', p =', p)
        
        s, p = mannwhitneyu(
            global_methods_report[method1]['scores'][score],
            global_methods_report[method2]['scores'][score],
            alternative=h1
        )
        print('mann-whitneyu: s =', round(int(s), -5), ', p =', p)
        
        print()
    print()
# Out:
# Adam - Lamb
# bleu < (28.0%)
# wilcoxon signed-rank: w = 15367670000 , p = 1.0
# mann-whitneyu: s = 84408700000 , p = 1.0
#
# meteor < (17.0%)
# wilcoxon signed-rank: w = 4495560000 , p = 1.0
# mann-whitneyu: s = 84943200000 , p = 1.0
#
# rouge-1F < (12.0%)
# wilcoxon signed-rank: w = 4255200000 , p = 1.0
# mann-whitneyu: s = 85350800000 , p = 1.0
#
# rouge-1P < (11.0%)
# wilcoxon signed-rank: w = 4368150000 , p = 1.0
# mann-whitneyu: s = 85624900000 , p = 1.0
#
# rouge-1R < (13.0%)
# wilcoxon signed-rank: w = 1938040000 , p = 1.0
# mann-whitneyu: s = 85334500000 , p = 1.0
#
# rouge-2F < (28.0%)
# wilcoxon signed-rank: w = 287180000 , p = 1.0
# mann-whitneyu: s = 86504300000 , p = 1.0
#
# rouge-2P < (28.0%)
# wilcoxon signed-rank: w = 289350000 , p = 1.0
# mann-whitneyu: s = 86492500000 , p = 1.0
#
# rouge-2R < (28.0%)
# wilcoxon signed-rank: w = 233460000 , p = 1.0
# mann-whitneyu: s = 86489700000 , p = 1.0
#
# rouge-lF < (12.0%)
# wilcoxon signed-rank: w = 3983750000 , p = 1.0
# mann-whitneyu: s = 85159300000 , p = 1.0
#
# rouge-lP < (12.0%)
# wilcoxon signed-rank: w = 3659010000 , p = 1.0
# mann-whitneyu: s = 85277700000 , p = 1.0
#
# rouge-lR < (12.0%)
# wilcoxon signed-rank: w = 1918420000 , p = 1.0
# mann-whitneyu: s = 85414200000 , p = 1.0
#
# symb-rouge-lF < (7.0%)
# wilcoxon signed-rank: w = 13952860000 , p = 1.0
# mann-whitneyu: s = 84248900000 , p = 1.0
#
# symb-rouge-lP < (4.0%)
# wilcoxon signed-rank: w = 13492660000 , p = 1.0
# mann-whitneyu: s = 86606500000 , p = 1.0
#
# symb-rouge-lR < (9.0%)
# wilcoxon signed-rank: w = 8013580000 , p = 1.0
# mann-whitneyu: s = 83830600000 , p = 1.0
#
#
# Adam - LaRAdam
# bleu < (47.0%)
# wilcoxon signed-rank: w = 12477250000 , p = 1.0
# mann-whitneyu: s = 77989900000 , p = 1.0
#
# meteor < (29.0%)
# wilcoxon signed-rank: w = 3878600000 , p = 1.0
# mann-whitneyu: s = 80408000000 , p = 1.0
#
# rouge-1F < (21.0%)
# wilcoxon signed-rank: w = 3718900000 , p = 1.0
# mann-whitneyu: s = 81076400000 , p = 1.0
#
# rouge-1P < (18.0%)
# wilcoxon signed-rank: w = 4198100000 , p = 1.0
# mann-whitneyu: s = 81929600000 , p = 1.0
#
# rouge-1R < (23.0%)
# wilcoxon signed-rank: w = 1795280000 , p = 1.0
# mann-whitneyu: s = 80837900000 , p = 1.0
#
# rouge-2F < (47.0%)
# wilcoxon signed-rank: w = 297810000 , p = 1.0
# mann-whitneyu: s = 83713500000 , p = 1.0
#
# rouge-2P < (47.0%)
# wilcoxon signed-rank: w = 313600000 , p = 1.0
# mann-whitneyu: s = 83718000000 , p = 1.0
#
# rouge-2R < (47.0%)
# wilcoxon signed-rank: w = 250750000 , p = 1.0
# mann-whitneyu: s = 83684000000 , p = 1.0
#
# rouge-lF < (21.0%)
# wilcoxon signed-rank: w = 3558670000 , p = 1.0
# mann-whitneyu: s = 80840300000 , p = 1.0
#
# rouge-lP < (19.0%)
# wilcoxon signed-rank: w = 3540170000 , p = 1.0
# mann-whitneyu: s = 81498700000 , p = 1.0
#
# rouge-lR < (22.0%)
# wilcoxon signed-rank: w = 1778740000 , p = 1.0
# mann-whitneyu: s = 80956600000 , p = 1.0
#
# symb-rouge-lF < (13.0%)
# wilcoxon signed-rank: w = 11632370000 , p = 1.0
# mann-whitneyu: s = 78154100000 , p = 1.0
#
# symb-rouge-lP < (6.0%)
# wilcoxon signed-rank: w = 13354250000 , p = 1.0
# mann-whitneyu: s = 84171600000 , p = 1.0
#
# symb-rouge-lR < (17.0%)
# wilcoxon signed-rank: w = 6134120000 , p = 1.0
# mann-whitneyu: s = 76667000000 , p = 1.0
#
#
# Adam - RAdam
# bleu < (26.0%)
# wilcoxon signed-rank: w = 13933820000 , p = 1.0
# mann-whitneyu: s = 84767400000 , p = 1.0
#
# meteor < (14.0%)
# wilcoxon signed-rank: w = 4024950000 , p = 1.0
# mann-whitneyu: s = 86067600000 , p = 1.0
#
# rouge-1F < (9.0%)
# wilcoxon signed-rank: w = 3788960000 , p = 1.0
# mann-whitneyu: s = 86757300000 , p = 1.0
#
# rouge-1P < (6.0%)
# wilcoxon signed-rank: w = 4126680000 , p = 1.0
# mann-whitneyu: s = 87623900000 , p = 1.0
#
# rouge-1R < (10.0%)
# wilcoxon signed-rank: w = 1743280000 , p = 1.0
# mann-whitneyu: s = 86289600000 , p = 1.0
#
# rouge-2F < (26.0%)
# wilcoxon signed-rank: w = 253390000 , p = 1.0
# mann-whitneyu: s = 86905600000 , p = 1.0
#
# rouge-2P < (25.0%)
# wilcoxon signed-rank: w = 262180000 , p = 1.0
# mann-whitneyu: s = 86913500000 , p = 1.0
#
# rouge-2R < (26.0%)
# wilcoxon signed-rank: w = 203950000 , p = 1.0
# mann-whitneyu: s = 86883300000 , p = 1.0
#
# rouge-lF < (10.0%)
# wilcoxon signed-rank: w = 3603230000 , p = 1.0
# mann-whitneyu: s = 86359600000 , p = 1.0
#
# rouge-lP < (8.0%)
# wilcoxon signed-rank: w = 3505620000 , p = 1.0
# mann-whitneyu: s = 86830100000 , p = 1.0
#
# rouge-lR < (10.0%)
# wilcoxon signed-rank: w = 1729400000 , p = 1.0
# mann-whitneyu: s = 86334900000 , p = 1.0
#
# symb-rouge-lF < (6.0%)
# wilcoxon signed-rank: w = 13013900000 , p = 1.0
# mann-whitneyu: s = 84823700000 , p = 1.0
#
# symb-rouge-lP < (3.0%)
# wilcoxon signed-rank: w = 12978130000 , p = 1.0
# mann-whitneyu: s = 87603300000 , p = 1.0
#
# symb-rouge-lR < (8.0%)
# wilcoxon signed-rank: w = 7429270000 , p = 1.0
# mann-whitneyu: s = 84424200000 , p = 1.0
#
#
# Adam - SGD
# bleu < (12.0%)
# wilcoxon signed-rank: w = 18067310000 , p = 1.0
# mann-whitneyu: s = 88242800000 , p = 1.0
#
# meteor < (8.0%)
# wilcoxon signed-rank: w = 5321310000 , p = 1.0
# mann-whitneyu: s = 87545100000 , p = 1.0
#
# rouge-1F < (8.0%)
# wilcoxon signed-rank: w = 4773220000 , p = 1.0
# mann-whitneyu: s = 87047500000 , p = 1.0
#
# rouge-1P < (10.0%)
# wilcoxon signed-rank: w = 4246310000 , p = 1.0
# mann-whitneyu: s = 86173400000 , p = 1.0
#
# rouge-1R < (7.0%)
# wilcoxon signed-rank: w = 2421630000 , p = 1.0
# mann-whitneyu: s = 87897400000 , p = 1.0
#
# rouge-2F < (13.0%)
# wilcoxon signed-rank: w = 397770000 , p = 1.0
# mann-whitneyu: s = 88727900000 , p = 1.0
#
# rouge-2P < (14.0%)
# wilcoxon signed-rank: w = 374490000 , p = 1.0
# mann-whitneyu: s = 88657200000 , p = 1.0
#
# rouge-2R < (12.0%)
# wilcoxon signed-rank: w = 342030000 , p = 1.0
# mann-whitneyu: s = 88736300000 , p = 1.0
#
# rouge-lF < (8.0%)
# wilcoxon signed-rank: w = 4584770000 , p = 1.0
# mann-whitneyu: s = 87041700000 , p = 1.0
#
# rouge-lP < (10.0%)
# wilcoxon signed-rank: w = 3683420000 , p = 1.0
# mann-whitneyu: s = 86028500000 , p = 1.0
#
# rouge-lR < (6.0%)
# wilcoxon signed-rank: w = 2391380000 , p = 1.0
# mann-whitneyu: s = 87933000000 , p = 1.0
#
# symb-rouge-lF < (4.0%)
# wilcoxon signed-rank: w = 15854220000 , p = 1.0
# mann-whitneyu: s = 87268000000 , p = 1.0
#
# symb-rouge-lP < (4.0%)
# wilcoxon signed-rank: w = 13060740000 , p = 1.0
# mann-whitneyu: s = 86120200000 , p = 1.0
#
# symb-rouge-lR < (3.0%)
# wilcoxon signed-rank: w = 9949190000 , p = 1.0
# mann-whitneyu: s = 88121600000 , p = 1.0
#
#
# Adam - LaSGD
# bleu > (1.0%)
# wilcoxon signed-rank: w = 20844360000 , p = 1.0
# mann-whitneyu: s = 92018300000 , p = 1.0
#
# meteor < (1.0%)
# wilcoxon signed-rank: w = 6240710000 , p = 1.0
# mann-whitneyu: s = 89807200000 , p = 1.0
#
# rouge-1F < (4.0%)
# wilcoxon signed-rank: w = 5507250000 , p = 1.0
# mann-whitneyu: s = 88863700000 , p = 1.0
#
# rouge-1P < (9.0%)
# wilcoxon signed-rank: w = 4405000000 , p = 1.0
# mann-whitneyu: s = 87244400000 , p = 1.0
#
# rouge-1R < (1.0%)
# wilcoxon signed-rank: w = 2767660000 , p = 1.0
# mann-whitneyu: s = 90099700000 , p = 1.0
#
# rouge-2F < (1.0%)
# wilcoxon signed-rank: w = 523280000 , p = 0.13044396578274187
# mann-whitneyu: s = 90565100000 , p = 0.9999999994070417
#
# rouge-2P < (3.0%)
# wilcoxon signed-rank: w = 483070000 , p = 0.9999999856919504
# mann-whitneyu: s = 90475900000 , p = 0.999999999999861
#
# rouge-2R > (0.0%)
# wilcoxon signed-rank: w = 446380000 , p = 0.9999999656268815
# mann-whitneyu: s = 90579200000 , p = 1.9031449195927625e-09
#
# rouge-lF < (4.0%)
# wilcoxon signed-rank: w = 5234010000 , p = 1.0
# mann-whitneyu: s = 88860700000 , p = 1.0
#
# rouge-lP < (9.0%)
# wilcoxon signed-rank: w = 3777820000 , p = 1.0
# mann-whitneyu: s = 87068600000 , p = 1.0
#
# rouge-lR < (1.0%)
# wilcoxon signed-rank: w = 2732230000 , p = 0.9999999999999999
# mann-whitneyu: s = 90109500000 , p = 0.9999999999999999
#
# symb-rouge-lF < (0.0%)
# wilcoxon signed-rank: w = 18071000000 , p = 1.0
# mann-whitneyu: s = 90670400000 , p = 0.9986776544004078
#
# symb-rouge-lP < (3.0%)
# wilcoxon signed-rank: w = 13008490000 , p = 1.0
# mann-whitneyu: s = 86575000000 , p = 1.0
#
# symb-rouge-lR > (1.0%)
# wilcoxon signed-rank: w = 11877900000 , p = 1.0
# mann-whitneyu: s = 92301400000 , p = 1.0
#
#
# Lamb - LaRAdam
# bleu < (16.0%)
# wilcoxon signed-rank: w = 15240420000 , p = 1.0
# mann-whitneyu: s = 84627200000 , p = 1.0
#
# meteor < (10.0%)
# wilcoxon signed-rank: w = 5443730000 , p = 1.0
# mann-whitneyu: s = 86506600000 , p = 1.0
#
# rouge-1F < (8.0%)
# wilcoxon signed-rank: w = 5031010000 , p = 1.0
# mann-whitneyu: s = 86732700000 , p = 1.0
#
# rouge-1P < (7.0%)
# wilcoxon signed-rank: w = 4980300000 , p = 1.0
# mann-whitneyu: s = 87358800000 , p = 1.0
#
# rouge-1R < (9.0%)
# wilcoxon signed-rank: w = 2251780000 , p = 1.0
# mann-whitneyu: s = 86500000000 , p = 1.0
#
# rouge-2F < (15.0%)
# wilcoxon signed-rank: w = 498550000 , p = 1.0
# mann-whitneyu: s = 88195000000 , p = 1.0
#
# rouge-2P < (15.0%)
# wilcoxon signed-rank: w = 486670000 , p = 1.0
# mann-whitneyu: s = 88218100000 , p = 1.0
#
# rouge-2R < (15.0%)
# wilcoxon signed-rank: w = 395470000 , p = 1.0
# mann-whitneyu: s = 88178900000 , p = 1.0
#
# rouge-lF < (8.0%)
# wilcoxon signed-rank: w = 4698840000 , p = 1.0
# mann-whitneyu: s = 86683200000 , p = 1.0
#
# rouge-lP < (7.0%)
# wilcoxon signed-rank: w = 4052720000 , p = 1.0
# mann-whitneyu: s = 87272200000 , p = 1.0
#
# rouge-lR < (9.0%)
# wilcoxon signed-rank: w = 2201950000 , p = 1.0
# mann-whitneyu: s = 86539300000 , p = 1.0
#
# symb-rouge-lF < (6.0%)
# wilcoxon signed-rank: w = 13438080000 , p = 1.0
# mann-whitneyu: s = 84952800000 , p = 1.0
#
# symb-rouge-lP < (2.0%)
# wilcoxon signed-rank: w = 12676980000 , p = 1.0
# mann-whitneyu: s = 88607500000 , p = 1.0
#
# symb-rouge-lR < (8.0%)
# wilcoxon signed-rank: w = 7595820000 , p = 1.0
# mann-whitneyu: s = 83857000000 , p = 1.0
#
#
# Lamb - RAdam
# bleu > (2.0%)
# wilcoxon signed-rank: w = 20068390000 , p = 0.9999751655590673
# mann-whitneyu: s = 91359200000 , p = 0.9989033496506691
#
# meteor > (2.0%)
# wilcoxon signed-rank: w = 7321330000 , p = 1.0
# mann-whitneyu: s = 92134800000 , p = 1.0
#
# rouge-1F > (3.0%)
# wilcoxon signed-rank: w = 6713530000 , p = 1.0
# mann-whitneyu: s = 92433500000 , p = 1.0
#
# rouge-1P > (4.0%)
# wilcoxon signed-rank: w = 6403470000 , p = 1.0
# mann-whitneyu: s = 93092500000 , p = 1.0
#
# rouge-1R > (2.0%)
# wilcoxon signed-rank: w = 3156140000 , p = 1.0
# mann-whitneyu: s = 91970300000 , p = 1.0
#
# rouge-2F > (2.0%)
# wilcoxon signed-rank: w = 662000000 , p = 0.9999999999237299
# mann-whitneyu: s = 91408600000 , p = 0.9999995463926246
#
# rouge-2P > (2.0%)
# wilcoxon signed-rank: w = 634240000 , p = 0.9999999999894812
# mann-whitneyu: s = 91433700000 , p = 0.9999999140665858
#
# rouge-2R > (1.0%)
# wilcoxon signed-rank: w = 527310000 , p = 0.9999987119847119
# mann-whitneyu: s = 91398800000 , p = 0.9999991716979929
#
# rouge-lF > (2.0%)
# wilcoxon signed-rank: w = 6212100000 , p = 1.0
# mann-whitneyu: s = 92214000000 , p = 1.0
#
# rouge-lP > (3.0%)
# wilcoxon signed-rank: w = 5178540000 , p = 1.0
# mann-whitneyu: s = 92616600000 , p = 1.0
#
# rouge-lR > (2.0%)
# wilcoxon signed-rank: w = 3078260000 , p = 1.0
# mann-whitneyu: s = 91933800000 , p = 1.0
#
# symb-rouge-lF > (1.0%)
# wilcoxon signed-rank: w = 17948860000 , p = 1.0
# mann-whitneyu: s = 91587700000 , p = 0.9999998114447124
#
# symb-rouge-lP > (1.0%)
# wilcoxon signed-rank: w = 14698130000 , p = 1.0
# mann-whitneyu: s = 92080100000 , p = 1.0
#
# symb-rouge-lR > (1.0%)
# wilcoxon signed-rank: w = 11246640000 , p = 1.0
# mann-whitneyu: s = 91577800000 , p = 0.9999997191615189
#
#
# Lamb - SGD
# bleu > (14.0%)
# wilcoxon signed-rank: w = 18736170000 , p = 1.0
# mann-whitneyu: s = 94828600000 , p = 1.0
#
# meteor > (8.0%)
# wilcoxon signed-rank: w = 6204900000 , p = 1.0
# mann-whitneyu: s = 93657100000 , p = 1.0
#
# rouge-1F > (4.0%)
# wilcoxon signed-rank: w = 5493920000 , p = 1.0
# mann-whitneyu: s = 92734500000 , p = 1.0
#
# rouge-1P > (1.0%)
# wilcoxon signed-rank: w = 4353320000 , p = 0.9999999999445633
# mann-whitneyu: s = 91490100000 , p = 0.9999942326561106
#
# rouge-1R > (6.0%)
# wilcoxon signed-rank: w = 2504440000 , p = 1.0
# mann-whitneyu: s = 93618600000 , p = 1.0
#
# rouge-2F > (13.0%)
# wilcoxon signed-rank: w = 554200000 , p = 1.0
# mann-whitneyu: s = 93256800000 , p = 1.0
#
# rouge-2P > (12.0%)
# wilcoxon signed-rank: w = 495200000 , p = 1.0
# mann-whitneyu: s = 93179700000 , p = 1.0
#
# rouge-2R > (14.0%)
# wilcoxon signed-rank: w = 429520000 , p = 1.0
# mann-whitneyu: s = 93286100000 , p = 1.0
#
# rouge-lF > (4.0%)
# wilcoxon signed-rank: w = 5077240000 , p = 1.0
# mann-whitneyu: s = 92917500000 , p = 1.0
#
# rouge-lP > (1.0%)
# wilcoxon signed-rank: w = 3571160000 , p = 1.0
# mann-whitneyu: s = 91663600000 , p = 0.9999999991466003
#
# rouge-lR > (6.0%)
# wilcoxon signed-rank: w = 2436420000 , p = 1.0
# mann-whitneyu: s = 93573600000 , p = 1.0
#
# symb-rouge-lF > (3.0%)
# wilcoxon signed-rank: w = 15550940000 , p = 1.0
# mann-whitneyu: s = 94048800000 , p = 1.0
#
# symb-rouge-lP < (0.0%)
# wilcoxon signed-rank: w = 10706220000 , p = 0.999999828936253
# mann-whitneyu: s = 90512700000 , p = 0.9999965527266734
#
# symb-rouge-lR > (5.0%)
# wilcoxon signed-rank: w = 10015390000 , p = 1.0
# mann-whitneyu: s = 95305000000 , p = 1.0
#
#
# Lamb - LaSGD
# bleu > (29.0%)
# wilcoxon signed-rank: w = 22179010000 , p = 1.0
# mann-whitneyu: s = 98563000000 , p = 1.0
#
# meteor > (15.0%)
# wilcoxon signed-rank: w = 7787700000 , p = 1.0
# mann-whitneyu: s = 95940200000 , p = 1.0
#
# rouge-1F > (8.0%)
# wilcoxon signed-rank: w = 6894130000 , p = 1.0
# mann-whitneyu: s = 94575500000 , p = 1.0
#
# rouge-1P > (2.0%)
# wilcoxon signed-rank: w = 5003080000 , p = 1.0
# mann-whitneyu: s = 92518000000 , p = 1.0
#
# rouge-1R > (11.0%)
# wilcoxon signed-rank: w = 3370270000 , p = 1.0
# mann-whitneyu: s = 95851500000 , p = 1.0
#
# rouge-2F > (27.0%)
# wilcoxon signed-rank: w = 795820000 , p = 1.0
# mann-whitneyu: s = 95107600000 , p = 1.0
#
# rouge-2P > (25.0%)
# wilcoxon signed-rank: w = 702250000 , p = 1.0
# mann-whitneyu: s = 95005600000 , p = 1.0
#
# rouge-2R > (28.0%)
# wilcoxon signed-rank: w = 655650000 , p = 1.0
# mann-whitneyu: s = 95142600000 , p = 1.0
#
# rouge-lF > (8.0%)
# wilcoxon signed-rank: w = 6329270000 , p = 1.0
# mann-whitneyu: s = 94763100000 , p = 1.0
#
# rouge-lP > (3.0%)
# wilcoxon signed-rank: w = 4041910000 , p = 1.0
# mann-whitneyu: s = 92646400000 , p = 1.0
#
# rouge-lR > (11.0%)
# wilcoxon signed-rank: w = 3291230000 , p = 1.0
# mann-whitneyu: s = 95779600000 , p = 1.0
#
# symb-rouge-lF > (7.0%)
# wilcoxon signed-rank: w = 18526190000 , p = 1.0
# mann-whitneyu: s = 97404800000 , p = 1.0
#
# symb-rouge-lP > (0.0%)
# wilcoxon signed-rank: w = 11308220000 , p = 0.8967356385070436
# mann-whitneyu: s = 90934900000 , p = 0.24460067947479647
#
# symb-rouge-lR > (10.0%)
# wilcoxon signed-rank: w = 12660530000 , p = 1.0
# mann-whitneyu: s = 99423900000 , p = 1.0
#
#
# LaRAdam - RAdam
# bleu > (17.0%)
# wilcoxon signed-rank: w = 24944200000 , p = 1.0
# mann-whitneyu: s = 97710200000 , p = 1.0
#
# meteor > (13.0%)
# wilcoxon signed-rank: w = 9296780000 , p = 1.0
# mann-whitneyu: s = 96653200000 , p = 1.0
#
# rouge-1F > (11.0%)
# wilcoxon signed-rank: w = 8494840000 , p = 1.0
# mann-whitneyu: s = 96721500000 , p = 1.0
#
# rouge-1P > (11.0%)
# wilcoxon signed-rank: w = 7793370000 , p = 1.0
# mann-whitneyu: s = 96815200000 , p = 1.0
#
# rouge-1R > (11.0%)
# wilcoxon signed-rank: w = 4671160000 , p = 1.0
# mann-whitneyu: s = 96483200000 , p = 1.0
#
# rouge-2F > (17.0%)
# wilcoxon signed-rank: w = 973270000 , p = 1.0
# mann-whitneyu: s = 94221700000 , p = 1.0
#
# rouge-2P > (17.0%)
# wilcoxon signed-rank: w = 919960000 , p = 1.0
# mann-whitneyu: s = 94227900000 , p = 1.0
#
# rouge-2R > (17.0%)
# wilcoxon signed-rank: w = 802100000 , p = 1.0
# mann-whitneyu: s = 94226500000 , p = 1.0
#
# rouge-lF > (10.0%)
# wilcoxon signed-rank: w = 8126050000 , p = 1.0
# mann-whitneyu: s = 96541100000 , p = 1.0
#
# rouge-lP > (10.0%)
# wilcoxon signed-rank: w = 6571970000 , p = 1.0
# mann-whitneyu: s = 96392000000 , p = 1.0
#
# rouge-lR > (11.0%)
# wilcoxon signed-rank: w = 4553010000 , p = 1.0
# mann-whitneyu: s = 96406300000 , p = 1.0
#
# symb-rouge-lF > (7.0%)
# wilcoxon signed-rank: w = 22301140000 , p = 1.0
# mann-whitneyu: s = 97648200000 , p = 1.0
#
# symb-rouge-lP > (3.0%)
# wilcoxon signed-rank: w = 16366720000 , p = 1.0
# mann-whitneyu: s = 94518500000 , p = 1.0
#
# symb-rouge-lR > (9.0%)
# wilcoxon signed-rank: w = 14948870000 , p = 1.0
# mann-whitneyu: s = 98704500000 , p = 1.0
#
#
# LaRAdam - SGD
# bleu > (31.0%)
# wilcoxon signed-rank: w = 27579000000 , p = 1.0
# mann-whitneyu: s = 101214600000 , p = 1.0
#
# meteor > (19.0%)
# wilcoxon signed-rank: w = 10920910000 , p = 1.0
# mann-whitneyu: s = 98197400000 , p = 1.0
#
# rouge-1F > (12.0%)
# wilcoxon signed-rank: w = 9814550000 , p = 1.0
# mann-whitneyu: s = 97029400000 , p = 1.0
#
# rouge-1P > (7.0%)
# wilcoxon signed-rank: w = 7569210000 , p = 1.0
# mann-whitneyu: s = 95082700000 , p = 1.0
#
# rouge-1R > (15.0%)
# wilcoxon signed-rank: w = 5666970000 , p = 1.0
# mann-whitneyu: s = 98154900000 , p = 1.0
#
# rouge-2F > (30.0%)
# wilcoxon signed-rank: w = 1368620000 , p = 1.0
# mann-whitneyu: s = 96076400000 , p = 1.0
#
# rouge-2P > (28.0%)
# wilcoxon signed-rank: w = 1249110000 , p = 1.0
# mann-whitneyu: s = 95966600000 , p = 1.0
#
# rouge-2R > (32.0%)
# wilcoxon signed-rank: w = 1200820000 , p = 1.0
# mann-whitneyu: s = 96123900000 , p = 1.0
#
# rouge-lF > (12.0%)
# wilcoxon signed-rank: w = 9300820000 , p = 1.0
# mann-whitneyu: s = 97261200000 , p = 1.0
#
# rouge-lP > (8.0%)
# wilcoxon signed-rank: w = 6408020000 , p = 1.0
# mann-whitneyu: s = 95348800000 , p = 1.0
#
# rouge-lR > (15.0%)
# wilcoxon signed-rank: w = 5545930000 , p = 1.0
# mann-whitneyu: s = 98070400000 , p = 1.0
#
# symb-rouge-lF > (9.0%)
# wilcoxon signed-rank: w = 24146580000 , p = 1.0
# mann-whitneyu: s = 100136700000 , p = 1.0
#
# symb-rouge-lP > (2.0%)
# wilcoxon signed-rank: w = 14962270000 , p = 1.0
# mann-whitneyu: s = 92906300000 , p = 1.0
#
# symb-rouge-lR > (13.0%)
# wilcoxon signed-rank: w = 17260600000 , p = 1.0
# mann-whitneyu: s = 102467200000 , p = 1.0
#
#
# LaRAdam - LaSGD
# bleu > (49.0%)
# wilcoxon signed-rank: w = 31384200000 , p = 1.0
# mann-whitneyu: s = 104937600000 , p = 1.0
#
# meteor > (27.0%)
# wilcoxon signed-rank: w = 12758300000 , p = 1.0
# mann-whitneyu: s = 100504000000 , p = 1.0
#
# rouge-1F > (17.0%)
# wilcoxon signed-rank: w = 11501380000 , p = 1.0
# mann-whitneyu: s = 98883900000 , p = 1.0
#
# rouge-1P > (9.0%)
# wilcoxon signed-rank: w = 8333170000 , p = 1.0
# mann-whitneyu: s = 96084200000 , p = 1.0
#
# rouge-1R > (21.0%)
# wilcoxon signed-rank: w = 6897750000 , p = 1.0
# mann-whitneyu: s = 100403200000 , p = 1.0
#
# rouge-2F > (46.0%)
# wilcoxon signed-rank: w = 1727700000 , p = 1.0
# mann-whitneyu: s = 97925700000 , p = 1.0
#
# rouge-2P > (43.0%)
# wilcoxon signed-rank: w = 1562850000 , p = 1.0
# mann-whitneyu: s = 97789200000 , p = 1.0
#
# rouge-2R > (48.0%)
# wilcoxon signed-rank: w = 1541890000 , p = 1.0
# mann-whitneyu: s = 97978100000 , p = 1.0
#
# rouge-lF > (17.0%)
# wilcoxon signed-rank: w = 10897890000 , p = 1.0
# mann-whitneyu: s = 99120200000 , p = 1.0
#
# rouge-lP > (10.0%)
# wilcoxon signed-rank: w = 6995310000 , p = 1.0
# mann-whitneyu: s = 96302500000 , p = 1.0
#
# rouge-lR > (21.0%)
# wilcoxon signed-rank: w = 6765780000 , p = 1.0
# mann-whitneyu: s = 100291500000 , p = 1.0
#
# symb-rouge-lF > (13.0%)
# wilcoxon signed-rank: w = 27701980000 , p = 1.0
# mann-whitneyu: s = 103471500000 , p = 1.0
#
# symb-rouge-lP > (2.0%)
# wilcoxon signed-rank: w = 15826640000 , p = 1.0
# mann-whitneyu: s = 93318100000 , p = 1.0
#
# symb-rouge-lR > (19.0%)
# wilcoxon signed-rank: w = 20486550000 , p = 1.0
# mann-whitneyu: s = 106526300000 , p = 1.0
#
#
# RAdam - SGD
# bleu > (12.0%)
# wilcoxon signed-rank: w = 23391960000 , p = 1.0
# mann-whitneyu: s = 94470000000 , p = 1.0
#
# meteor > (5.0%)
# wilcoxon signed-rank: w = 7871140000 , p = 1.0
# mann-whitneyu: s = 92522200000 , p = 1.0
#
# rouge-1F > (1.0%)
# wilcoxon signed-rank: w = 6897960000 , p = 1.0
# mann-whitneyu: s = 91305200000 , p = 0.9961818682110822
#
# rouge-1P < (4.0%)
# wilcoxon signed-rank: w = 5386750000 , p = 1.0
# mann-whitneyu: s = 89430700000 , p = 1.0
#
# rouge-1R > (4.0%)
# wilcoxon signed-rank: w = 3757060000 , p = 1.0
# mann-whitneyu: s = 92656100000 , p = 1.0
#
# rouge-2F > (12.0%)
# wilcoxon signed-rank: w = 862420000 , p = 1.0
# mann-whitneyu: s = 92856900000 , p = 1.0
#
# rouge-2P > (10.0%)
# wilcoxon signed-rank: w = 800490000 , p = 1.0
# mann-whitneyu: s = 92758200000 , p = 1.0
#
# rouge-2R > (13.0%)
# wilcoxon signed-rank: w = 744590000 , p = 1.0
# mann-whitneyu: s = 92894900000 , p = 1.0
#
# rouge-lF > (2.0%)
# wilcoxon signed-rank: w = 6614290000 , p = 1.0
# mann-whitneyu: s = 91714600000 , p = 0.999999999917537
#
# rouge-lP < (2.0%)
# wilcoxon signed-rank: w = 4670330000 , p = 1.0
# mann-whitneyu: s = 90086900000 , p = 1.0
#
# rouge-lR > (4.0%)
# wilcoxon signed-rank: w = 3688660000 , p = 1.0
# mann-whitneyu: s = 92647400000 , p = 1.0
#
# symb-rouge-lF > (3.0%)
# wilcoxon signed-rank: w = 20014110000 , p = 1.0
# mann-whitneyu: s = 93474300000 , p = 1.0
#
# symb-rouge-lP < (1.0%)
# wilcoxon signed-rank: w = 13979210000 , p = 1.0
# mann-whitneyu: s = 89450200000 , p = 1.0
#
# symb-rouge-lR > (4.0%)
# wilcoxon signed-rank: w = 13434450000 , p = 1.0
# mann-whitneyu: s = 94724400000 , p = 1.0
#
#
# RAdam - LaSGD
# bleu > (27.0%)
# wilcoxon signed-rank: w = 26465500000 , p = 1.0
# mann-whitneyu: s = 98195200000 , p = 1.0
#
# meteor > (12.0%)
# wilcoxon signed-rank: w = 9236190000 , p = 1.0
# mann-whitneyu: s = 94805000000 , p = 1.0
#
# rouge-1F > (5.0%)
# wilcoxon signed-rank: w = 8025590000 , p = 1.0
# mann-whitneyu: s = 93142700000 , p = 1.0
#
# rouge-1P < (2.0%)
# wilcoxon signed-rank: w = 5769560000 , p = 1.0
# mann-whitneyu: s = 90487400000 , p = 0.9999992594069492
#
# rouge-1R > (9.0%)
# wilcoxon signed-rank: w = 4448240000 , p = 1.0
# mann-whitneyu: s = 94887200000 , p = 1.0
#
# rouge-2F > (25.0%)
# wilcoxon signed-rank: w = 1102900000 , p = 1.0
# mann-whitneyu: s = 94705400000 , p = 1.0
#
# rouge-2P > (22.0%)
# wilcoxon signed-rank: w = 1014170000 , p = 1.0
# mann-whitneyu: s = 94584400000 , p = 1.0
#
# rouge-2R > (27.0%)
# wilcoxon signed-rank: w = 964400000 , p = 1.0
# mann-whitneyu: s = 94748300000 , p = 1.0
#
# rouge-lF > (6.0%)
# wilcoxon signed-rank: w = 7611080000 , p = 1.0
# mann-whitneyu: s = 93554200000 , p = 1.0
#
# rouge-lP < (0.0%)
# wilcoxon signed-rank: w = 4904820000 , p = 0.9470041892712292
# mann-whitneyu: s = 91090000000 , p = 0.23432984278002977
#
# rouge-lR > (9.0%)
# wilcoxon signed-rank: w = 4378880000 , p = 1.0
# mann-whitneyu: s = 94850900000 , p = 1.0
#
# symb-rouge-lF > (6.0%)
# wilcoxon signed-rank: w = 22592440000 , p = 1.0
# mann-whitneyu: s = 96828100000 , p = 1.0
#
# symb-rouge-lP < (1.0%)
# wilcoxon signed-rank: w = 14112710000 , p = 1.0
# mann-whitneyu: s = 89886500000 , p = 1.0
#
# symb-rouge-lR > (10.0%)
# wilcoxon signed-rank: w = 15990530000 , p = 1.0
# mann-whitneyu: s = 98818500000 , p = 1.0
#
#
# SGD - LaSGD
# bleu > (13.0%)
# wilcoxon signed-rank: w = 13400200000 , p = 1.0
# mann-whitneyu: s = 94752600000 , p = 1.0
#
# meteor > (7.0%)
# wilcoxon signed-rank: w = 4190710000 , p = 1.0
# mann-whitneyu: s = 93300600000 , p = 1.0
#
# rouge-1F > (4.0%)
# wilcoxon signed-rank: w = 3779090000 , p = 1.0
# mann-whitneyu: s = 92857900000 , p = 1.0
#
# rouge-1P > (2.0%)
# wilcoxon signed-rank: w = 3032480000 , p = 1.0
# mann-whitneyu: s = 92022300000 , p = 1.0
#
# rouge-1R > (5.0%)
# wilcoxon signed-rank: w = 1596470000 , p = 1.0
# mann-whitneyu: s = 93248200000 , p = 1.0
#
# rouge-2F > (12.0%)
# wilcoxon signed-rank: w = 326120000 , p = 1.0
# mann-whitneyu: s = 92865100000 , p = 1.0
#
# rouge-2P > (11.0%)
# wilcoxon signed-rank: w = 294920000 , p = 1.0
# mann-whitneyu: s = 92835700000 , p = 1.0
#
# rouge-2R > (12.0%)
# wilcoxon signed-rank: w = 244720000 , p = 1.0
# mann-whitneyu: s = 92872900000 , p = 1.0
#
# rouge-lF > (4.0%)
# wilcoxon signed-rank: w = 3421140000 , p = 1.0
# mann-whitneyu: s = 92861900000 , p = 1.0
#
# rouge-lP > (2.0%)
# wilcoxon signed-rank: w = 2433400000 , p = 1.0
# mann-whitneyu: s = 91986600000 , p = 1.0
#
# rouge-lR > (5.0%)
# wilcoxon signed-rank: w = 1559970000 , p = 1.0
# mann-whitneyu: s = 93221500000 , p = 1.0
#
# symb-rouge-lF > (3.0%)
# wilcoxon signed-rank: w = 10992860000 , p = 1.0
# mann-whitneyu: s = 94392200000 , p = 1.0
#
# symb-rouge-lP > (0.0%)
# wilcoxon signed-rank: w = 7573890000 , p = 0.9999999999999761
# mann-whitneyu: s = 91432200000 , p = 0.9999254118836779
#
# symb-rouge-lR > (5.0%)
# wilcoxon signed-rank: w = 6995100000 , p = 1.0
# mann-whitneyu: s = 95167900000 , p = 1.0

# %%
for method in local_methods_report:
    print(f'LaRAdam_global - {method}_local')
    for score in global_methods_report['LaRAdam']['score']:
        print(score, end=' ')
        h1 = None
        if global_methods_report['LaRAdam']['score'][score] > local_methods_report[method]['score'][score]:
            pc = round(100 * (global_methods_report['LaRAdam']['score'][score] - local_methods_report[method]['score'][score]) / local_methods_report[method]['score'][score], 2)
            print('>', f'({pc}%)', end=' ')
            h1 = 'less'
        else:
            pc = round(100 * (local_methods_report[method]['score'][score] - global_methods_report['LaRAdam']['score'][score]) / global_methods_report['LaRAdam']['score'][score], 2)
            print('<', f'({pc}%)', end=' ')
            h1 = 'greater'
            
        print()
        w, p = wilcoxon(
            global_methods_report['LaRAdam']['scores'][score],
            local_methods_report[method]['scores'][score],
            alternative=h1
        )
        print('wilcoxon signed-rank: w =', round(int(w), -4), ', p =', p)
        
        s, p = mannwhitneyu(
            global_methods_report['LaRAdam']['scores'][score],
            local_methods_report[method]['scores'][score],
            alternative=h1
        )
        print('mann-whitneyu: s =', round(int(s), -5), ', p =', p)
        
        print()
    print()
# Out:
# LaRAdam_global - Adadelta_local
# bleu < (1.57%)
# wilcoxon signed-rank: w = 11409070000 , p = 1.0
# mann-whitneyu: s = 90417300000 , p = 0.999999923458836
#
# meteor < (1.25%)
# wilcoxon signed-rank: w = 3475030000 , p = 1.0
# mann-whitneyu: s = 90629900000 , p = 0.9996891254603857
#
# rouge-1F < (0.18%)
# wilcoxon signed-rank: w = 3251340000 , p = 0.9994266304553264
# mann-whitneyu: s = 90972200000 , p = 0.6391436223323287
#
# rouge-1P > (0.67%)
# wilcoxon signed-rank: w = 3145140000 , p = 1.0
# mann-whitneyu: s = 91379000000 , p = 0.9995881376175807
#
# rouge-1R < (0.66%)
# wilcoxon signed-rank: w = 1362200000 , p = 1.0
# mann-whitneyu: s = 90712100000 , p = 0.9966869535974676
#
# rouge-2F < (2.18%)
# wilcoxon signed-rank: w = 313150000 , p = 1.0
# mann-whitneyu: s = 90529800000 , p = 0.9999999909090111
#
# rouge-2P < (2.08%)
# wilcoxon signed-rank: w = 293920000 , p = 1.0
# mann-whitneyu: s = 90540700000 , p = 0.9999999821253541
#
# rouge-2R < (2.32%)
# wilcoxon signed-rank: w = 218890000 , p = 1.0
# mann-whitneyu: s = 90521800000 , p = 0.9999999948799023
#
# rouge-lF < (0.05%)
# wilcoxon signed-rank: w = 3196680000 , p = 0.8269379230111746
# mann-whitneyu: s = 91039400000 , p = 0.4011851218676353
#
# rouge-lP > (1.07%)
# wilcoxon signed-rank: w = 2791880000 , p = 1.0
# mann-whitneyu: s = 91632900000 , p = 0.9999999942575102
#
# rouge-lR < (0.67%)
# wilcoxon signed-rank: w = 1311700000 , p = 1.0
# mann-whitneyu: s = 90709000000 , p = 0.9969577867631304
#
# symb-rouge-lF < (0.26%)
# wilcoxon signed-rank: w = 9807790000 , p = 0.9999999998645758
# mann-whitneyu: s = 90751200000 , p = 0.989373897039965
#
# symb-rouge-lP > (0.53%)
# wilcoxon signed-rank: w = 8548260000 , p = 1.0
# mann-whitneyu: s = 91748500000 , p = 0.9999999999860807
#
# symb-rouge-lR < (0.64%)
# wilcoxon signed-rank: w = 5398630000 , p = 1.0
# mann-whitneyu: s = 90389200000 , p = 0.999999983262862
#
#
# LaRAdam_global - Barzilai-Borwein_local
# bleu < (5.92%)
# wilcoxon signed-rank: w = 8880410000 , p = 1.0
# mann-whitneyu: s = 88588900000 , p = 1.0
#
# meteor < (3.69%)
# wilcoxon signed-rank: w = 2723600000 , p = 1.0
# mann-whitneyu: s = 89265000000 , p = 1.0
#
# rouge-1F < (2.41%)
# wilcoxon signed-rank: w = 2536400000 , p = 1.0
# mann-whitneyu: s = 89671000000 , p = 1.0
#
# rouge-1P < (1.23%)
# wilcoxon signed-rank: w = 2548010000 , p = 1.0
# mann-whitneyu: s = 90254100000 , p = 0.9999999999972748
#
# rouge-1R < (3.06%)
# wilcoxon signed-rank: w = 983860000 , p = 1.0
# mann-whitneyu: s = 89311800000 , p = 1.0
#
# rouge-2F < (4.4%)
# wilcoxon signed-rank: w = 238470000 , p = 1.0
# mann-whitneyu: s = 89984000000 , p = 1.0
#
# rouge-2P < (4.04%)
# wilcoxon signed-rank: w = 229640000 , p = 1.0
# mann-whitneyu: s = 90017200000 , p = 1.0
#
# rouge-2R < (4.59%)
# wilcoxon signed-rank: w = 163040000 , p = 1.0
# mann-whitneyu: s = 89974600000 , p = 1.0
#
# rouge-lF < (2.33%)
# wilcoxon signed-rank: w = 2479680000 , p = 1.0
# mann-whitneyu: s = 89686600000 , p = 1.0
#
# rouge-lP < (1.02%)
# wilcoxon signed-rank: w = 2243280000 , p = 1.0
# mann-whitneyu: s = 90394000000 , p = 0.999999992959549
#
# rouge-lR < (3.04%)
# wilcoxon signed-rank: w = 945530000 , p = 1.0
# mann-whitneyu: s = 89324100000 , p = 1.0
#
# symb-rouge-lF < (1.81%)
# wilcoxon signed-rank: w = 7705820000 , p = 1.0
# mann-whitneyu: s = 89057200000 , p = 1.0
#
# symb-rouge-lP > (0.13%)
# wilcoxon signed-rank: w = 7408250000 , p = 0.9999999999998306
# mann-whitneyu: s = 91223000000 , p = 0.9719810788882182
#
# symb-rouge-lR < (2.8%)
# wilcoxon signed-rank: w = 3939990000 , p = 1.0
# mann-whitneyu: s = 88244900000 , p = 1.0
#
#
# LaRAdam_global - LaRAdam_local
# bleu < (5.35%)
# wilcoxon signed-rank: w = 9827700000 , p = 1.0
# mann-whitneyu: s = 88825500000 , p = 1.0
#
# meteor < (3.44%)
# wilcoxon signed-rank: w = 3031660000 , p = 1.0
# mann-whitneyu: s = 89462100000 , p = 1.0
#
# rouge-1F < (2.09%)
# wilcoxon signed-rank: w = 2827980000 , p = 1.0
# mann-whitneyu: s = 89872300000 , p = 1.0
#
# rouge-1P < (0.88%)
# wilcoxon signed-rank: w = 2823210000 , p = 1.0
# mann-whitneyu: s = 90466400000 , p = 0.9999996515771429
#
# rouge-1R < (2.7%)
# wilcoxon signed-rank: w = 1141150000 , p = 1.0
# mann-whitneyu: s = 89541900000 , p = 1.0
#
# rouge-2F < (4.38%)
# wilcoxon signed-rank: w = 258530000 , p = 1.0
# mann-whitneyu: s = 90021300000 , p = 1.0
#
# rouge-2P < (4.07%)
# wilcoxon signed-rank: w = 249440000 , p = 1.0
# mann-whitneyu: s = 90051000000 , p = 1.0
#
# rouge-2R < (4.57%)
# wilcoxon signed-rank: w = 179720000 , p = 1.0
# mann-whitneyu: s = 90013100000 , p = 1.0
#
# rouge-lF < (1.88%)
# wilcoxon signed-rank: w = 2826980000 , p = 1.0
# mann-whitneyu: s = 89964800000 , p = 1.0
#
# rouge-lP < (0.4%)
# wilcoxon signed-rank: w = 2567070000 , p = 0.9999963013408507
# mann-whitneyu: s = 90757100000 , p = 0.9902942964465833
#
# rouge-lR < (2.69%)
# wilcoxon signed-rank: w = 1095140000 , p = 1.0
# mann-whitneyu: s = 89551500000 , p = 1.0
#
# symb-rouge-lF < (1.55%)
# wilcoxon signed-rank: w = 8651810000 , p = 1.0
# mann-whitneyu: s = 89317800000 , p = 1.0
#
# symb-rouge-lP > (0.41%)
# wilcoxon signed-rank: w = 8290650000 , p = 1.0
# mann-whitneyu: s = 91542300000 , p = 0.9999991919196691
#
# symb-rouge-lR < (2.59%)
# wilcoxon signed-rank: w = 4477230000 , p = 1.0
# mann-whitneyu: s = 88442800000 , p = 1.0
#
#
# LaRAdam_global - SVRG_local
# bleu < (0.42%)
# wilcoxon signed-rank: w = 11712100000 , p = 0.9999999998204918
# mann-whitneyu: s = 90965100000 , p = 0.6597882379741413
#
# meteor < (0.66%)
# wilcoxon signed-rank: w = 3577540000 , p = 0.999991378287336
# mann-whitneyu: s = 90898000000 , p = 0.8459959052710453
#
# rouge-1F > (0.08%)
# wilcoxon signed-rank: w = 3313080000 , p = 0.8358681611921384
# mann-whitneyu: s = 91111900000 , p = 0.8172427298752547
#
# rouge-1P > (0.64%)
# wilcoxon signed-rank: w = 3132830000 , p = 0.999999999999944
# mann-whitneyu: s = 91384600000 , p = 0.9996592231773812
#
# rouge-1R < (0.18%)
# wilcoxon signed-rank: w = 1418510000 , p = 0.999068738531287
# mann-whitneyu: s = 90978100000 , p = 0.6195288128438903
#
# rouge-2F < (1.28%)
# wilcoxon signed-rank: w = 320690000 , p = 1.0
# mann-whitneyu: s = 90773200000 , p = 0.9973784161567287
#
# rouge-2P < (1.19%)
# wilcoxon signed-rank: w = 299950000 , p = 0.9999999999999997
# mann-whitneyu: s = 90784900000 , p = 0.9960841376718126
#
# rouge-2R < (1.33%)
# wilcoxon signed-rank: w = 227720000 , p = 1.0
# mann-whitneyu: s = 90776400000 , p = 0.9970834007953013
#
# rouge-lF > (0.2%)
# wilcoxon signed-rank: w = 3240700000 , p = 0.9993706931791071
# mann-whitneyu: s = 91166300000 , p = 0.9185774889510679
#
# rouge-lP > (0.97%)
# wilcoxon signed-rank: w = 2749690000 , p = 1.0
# mann-whitneyu: s = 91577500000 , p = 0.9999999010105508
#
# rouge-lR < (0.21%)
# wilcoxon signed-rank: w = 1362740000 , p = 0.9996531178092346
# mann-whitneyu: s = 90968900000 , p = 0.6509211840874947
#
# symb-rouge-lF > (0.09%)
# wilcoxon signed-rank: w = 10114290000 , p = 0.9976464642524793
# mann-whitneyu: s = 91110700000 , p = 0.8092976015237707
#
# symb-rouge-lP > (0.3%)
# wilcoxon signed-rank: w = 8453060000 , p = 0.9999999999999999
# mann-whitneyu: s = 91402200000 , p = 0.9997924718455792
#
# symb-rouge-lR > (0.01%)
# wilcoxon signed-rank: w = 5699750000 , p = 0.7234180178300248
# mann-whitneyu: s = 91026500000 , p = 0.5521068936065148
#
#
# LaRAdam_global - SWA_local
# bleu < (5.58%)
# wilcoxon signed-rank: w = 8953030000 , p = 1.0
# mann-whitneyu: s = 88735600000 , p = 1.0
#
# meteor < (3.53%)
# wilcoxon signed-rank: w = 2732890000 , p = 1.0
# mann-whitneyu: s = 89393600000 , p = 1.0
#
# rouge-1F < (2.26%)
# wilcoxon signed-rank: w = 2551300000 , p = 1.0
# mann-whitneyu: s = 89772000000 , p = 1.0
#
# rouge-1P < (1.13%)
# wilcoxon signed-rank: w = 2557190000 , p = 1.0
# mann-whitneyu: s = 90328600000 , p = 0.9999999997457607
#
# rouge-1R < (2.8%)
# wilcoxon signed-rank: w = 1007680000 , p = 1.0
# mann-whitneyu: s = 89472600000 , p = 1.0
#
# rouge-2F < (4.44%)
# wilcoxon signed-rank: w = 238650000 , p = 1.0
# mann-whitneyu: s = 90003500000 , p = 1.0
#
# rouge-2P < (4.18%)
# wilcoxon signed-rank: w = 228530000 , p = 1.0
# mann-whitneyu: s = 90030500000 , p = 1.0
#
# rouge-2R < (4.56%)
# wilcoxon signed-rank: w = 164660000 , p = 1.0
# mann-whitneyu: s = 90001600000 , p = 1.0
#
# rouge-lF < (2.15%)
# wilcoxon signed-rank: w = 2499150000 , p = 1.0
# mann-whitneyu: s = 89802000000 , p = 1.0
#
# rouge-lP < (0.86%)
# wilcoxon signed-rank: w = 2252510000 , p = 1.0
# mann-whitneyu: s = 90491600000 , p = 0.9999991090805859
#
# rouge-lR < (2.8%)
# wilcoxon signed-rank: w = 967130000 , p = 1.0
# mann-whitneyu: s = 89478400000 , p = 1.0
#
# symb-rouge-lF < (1.68%)
# wilcoxon signed-rank: w = 7800030000 , p = 1.0
# mann-whitneyu: s = 89208300000 , p = 1.0
#
# symb-rouge-lP > (0.18%)
# wilcoxon signed-rank: w = 7437490000 , p = 1.0
# mann-whitneyu: s = 91262700000 , p = 0.9883956915715152
#
# symb-rouge-lR < (2.59%)
# wilcoxon signed-rank: w = 4019410000 , p = 1.0
# mann-whitneyu: s = 88453000000 , p = 1.0
